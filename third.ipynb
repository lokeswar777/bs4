# %%
from bs4 import BeautifulSoup
import requests

html_text=requests.get('https://www.timesjobs.com/candidate/job-search.html?searchType=personalizedSearch&from=submit&searchTextSrc=&searchTextText=&txtKeywords=python&txtLocation=').text
soup=BeautifulSoup(html_text,'lxml')
jobs=soup.find_all('li',class_="clearfix job-bx wht-shd-bx")
jobs
# Out:
# [<li class="clearfix job-bx wht-shd-bx">
#  <header class="clearfix">
#  <!--
#  -->
#  <!-- -->
#  <h2>
#  <a href="https://www.timesjobs.com/job-detail/python-developer-art-technology-and-software-india-pvt-ltd-cochin-kochi-ernakulam-2-to-3-yrs-jobid-LwuulL9CkdpzpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','70509621','rest  ,  python  ,  database  ,  django  ,  api','Cochin/ Kochi/ Ernakulam','2 - 3','IT Software : Software Products &amp; Services','1','' )" target="_blank">
#  <strong class="blkclor">Python</strong> Developer</a> </h2>
#  <h3 class="joblist-comp-name">
#      art technology and software india pvt ltd
#
#      </h3>
#  </header>
#  <ul class="top-jd-dtl clearfix">
#  <li><i class="material-icons">card_travel</i>2 - 3 yrs</li>
#  <li>
#  <i class="material-icons">location_on</i>
#  <span title="Cochin/ Kochi/ Ernakulam">Cochin/ Kochi/ Ernakulam</span>
#  </li>
#  </ul>
#  <ul class="list-job-dtl clearfix">
#  <li>
#  <label>Job Description:</label>
#  ResponsibilitiesIn-depth knowledge of Python and Django framework 2  yr experience - Must HaveAPI design based on RESTBuild scalable and performance application with large dat... <a href="https://www.timesjobs.com/job-detail/python-developer-art-technology-and-software-india-pvt-ltd-cochin-kochi-ernakulam-2-to-3-yrs-jobid-LwuulL9CkdpzpSvf__PLUS__uAgZw==&amp;source=srp" target="_blank">More Details</a>
#  </li>
#  <li>
#  <label>KeySkills:</label>
#  <span class="srp-skills">
#  <span>rest</span>
#  <span><strong class="blkclor">python</strong></span>
#  <span>database</span>
#  <span>django</span>
#  <span>api</span>
#  </span> </li>
#  <!--
#              <li>
#                <i class="material-icons">location_on</i>
#                Cochin/ Kochi/ Ernakulam
#                </li>
#  -->
#  </ul>
#  <div class="list-job-bt clearfix">
#  <div class="list-action">
#  <div class="applied-dtl clearfix" id="showPostApplyData_70509621">
#  <a class="waves-effect waves-light btn" href="javascript:callExtJobApply('70509621','adId=LwuulL9CkdpzpSvf__PLUS__uAgZw==&amp;compName=Career Progress Consultants','TJPFSRP');" onclick="trackClickEvent('View_AND_Apply_SRP','from_srp_externalJobs');logViewUSBT('apply','70509621','rest  ,  python  ,  database  ,  django  ,  api','Cochin/ Kochi/ Ernakulam','2 - 3','IT Software : Software Products &amp; Services','1','')">Apply</a>
#  <span class="jobs-status clearfix">
#  <!--
#         <i class="material-icons trnding-up" title="Recently posted job, Recruiter is actively looking for candidates">check_circle</i>
#
#  -->
#  </span>
#  <span class="sim-posted">
#  <span>Posted few days ago</span>
#  </span>
#  </div>
#  </div>
#  </div>
#  </li>,
#  <li class="clearfix job-bx wht-shd-bx">
#  <header class="clearfix">
#  <!--
#  -->
#  <!-- -->
#  <h2>
#  <a href="https://www.timesjobs.com/job-detail/python-trainer-connecting-2-work-calicut-kozhikode-0-to-3-yrs-jobid-MFJXBwZBWVhzpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','70491700','rest  ,  python  ,  django  ,  mongodb','Calicut/ Kozhikode','0 - 3','IT Software : Software Products &amp; Services','2','' )" target="_blank">
#  <strong class="blkclor">PYTHON</strong> TRAINER</a> </h2>
#  <h3 class="joblist-comp-name">
#      CONNECTING 2 WORK
#
#      </h3>
#  </header>
#  <ul class="top-jd-dtl clearfix">
#  <li><i class="material-icons">card_travel</i>0 - 3 yrs</li>
#  <li>
#  <i class="material-icons">location_on</i>
#  <span title="Calicut/ Kozhikode">Calicut/ Kozhikode</span>
#  </li>
#  </ul>
#  <ul class="list-job-dtl clearfix">
#  <li>
#  <label>Job Description:</label>
#  Job Description We are looking for candidates with Proper  &amp;  very good knowledge in Django  Flask framework  ( Mandatory )  , Coaching Experience  ( Mandatory )  Good Communi... <a href="https://www.timesjobs.com/job-detail/python-trainer-connecting-2-work-calicut-kozhikode-0-to-3-yrs-jobid-MFJXBwZBWVhzpSvf__PLUS__uAgZw==&amp;source=srp" target="_blank">More Details</a>
#  </li>
#  <li>
#  <label>KeySkills:</label>
#  <span class="srp-skills">
#  <span>rest</span>
#  <span><strong class="blkclor">python</strong></span>
#  <span>django</span>
#  <span>mongodb</span>
#  </span> </li>
#  <!--
#              <li>
#                <i class="material-icons">location_on</i>
#                Calicut/ Kozhikode
#                </li>
#  -->
#  </ul>
#  <div class="list-job-bt clearfix">
#  <div class="list-action">
#  <div class="applied-dtl clearfix" id="showPostApplyData_70491700">
#  <a class="waves-effect waves-light btn" href="javascript:callExtJobApply('70491700','adId=MFJXBwZBWVhzpSvf__PLUS__uAgZw==&amp;compName=Career Progress Consultants','TJPFSRP');" onclick="trackClickEvent('View_AND_Apply_SRP','from_srp_externalJobs');logViewUSBT('apply','70491700','rest  ,  python  ,  django  ,  mongodb','Calicut/ Kozhikode','0 - 3','IT Software : Software Products &amp; Services','2','')">Apply</a>
#  <span class="jobs-status clearfix">
#  <!--
#  -->
#  </span>
#  <span class="sim-posted">
#  <span>Posted few days ago</span>
#  </span>
#  </div>
#  </div>
#  </div>
#  </li>,
#  <li class="clearfix job-bx wht-shd-bx">
#  <header class="clearfix">
#  <!--
#  -->
#  <!-- -->
#  <h2>
#  <a href="https://www.timesjobs.com/job-detail/python-developer-young-minds-technology-solutions-pvt-ltd-tirupati-0-to-3-yrs-jobid-CF7nNW8ikyZzpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','70598270','python  ,  html5  ,  storage  ,  javascript  ,  security  ,  django','Tirupati','0 - 3','IT Software : Software Products &amp; Services','3','' )" target="_blank">
#  <strong class="blkclor">Python</strong> Developer</a> </h2>
#  <h3 class="joblist-comp-name">
#      young minds technology solutions pvt ltd
#
#      </h3>
#  </header>
#  <ul class="top-jd-dtl clearfix">
#  <li><i class="material-icons">card_travel</i>0 - 3 yrs</li>
#  <li>
#  <i class="material-icons">location_on</i>
#  <span title="Tirupati">Tirupati</span>
#  </li>
#  </ul>
#  <ul class="list-job-dtl clearfix">
#  <li>
#  <label>Job Description:</label>
#  Roles  &amp;  ResponsibilitiesWrite reusable ,  testable ,  and efficient codeDesign and implement of low-latency ,  high-availability ,  and performant applicationsIntegration of... <a href="https://www.timesjobs.com/job-detail/python-developer-young-minds-technology-solutions-pvt-ltd-tirupati-0-to-3-yrs-jobid-CF7nNW8ikyZzpSvf__PLUS__uAgZw==&amp;source=srp" target="_blank">More Details</a>
#  </li>
#  <li>
#  <label>KeySkills:</label>
#  <span class="srp-skills">
#  <span><strong class="blkclor">python</strong></span>
#  <span>html5</span>
#  <span>storage</span>
#  <span>javascript</span>
#  <span>security</span>
#  <span>django</span>
#  </span> </li>
#  <!--
#              <li>
#                <i class="material-icons">location_on</i>
#                Tirupati
#                </li>
#  -->
#  </ul>
#  <div class="list-job-bt clearfix">
#  <div class="list-action">
#  <div class="applied-dtl clearfix" id="showPostApplyData_70598270">
#  <a class="waves-effect waves-light btn" href="javascript:callExtJobApply('70598270','adId=CF7nNW8ikyZzpSvf__PLUS__uAgZw==&amp;compName=Career Progress Consultants','TJPFSRP');" onclick="trackClickEvent('View_AND_Apply_SRP','from_srp_externalJobs');logViewUSBT('apply','70598270','python  ,  html5  ,  storage  ,  javascript  ,  security  ,  django','Tirupati','0 - 3','IT Software : Software Products &amp; Services','3','')">Apply</a>
#  <span class="jobs-status clearfix">
#  <!--
#         <i class="material-icons trnding-up" title="Recently posted job, Recruiter is actively looking for candidates">check_circle</i>
#
#  -->
#  </span>
#  <span class="sim-posted">
#  <span>Posted 6 days ago</span>
#  </span>
#  </div>
#  </div>
#  </div>
#  </li>,
#  <li class="clearfix job-bx wht-shd-bx">
#  <header class="clearfix">
#  <!--
#  -->
#  <!-- -->
#  <h2>
#  <a href="https://www.timesjobs.com/job-detail/python-engineer-east-india-securities-ltd-kolkata-2-to-5-yrs-jobid-O9JSjUglX3hzpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','70471066','python  ,  hadoop  ,  machine learning','Kolkata','2 - 5','IT Software : Software Products &amp; Services','4','' )" target="_blank">
#  <strong class="blkclor">Python</strong> Engineer</a> </h2>
#  <h3 class="joblist-comp-name">
#      east india securities ltd.
#
#      </h3>
#  </header>
#  <ul class="top-jd-dtl clearfix">
#  <li><i class="material-icons">card_travel</i>2 - 5 yrs</li>
#  <li>
#  <i class="material-icons">location_on</i>
#  <span title="Kolkata">Kolkata</span>
#  </li>
#  </ul>
#  <ul class="list-job-dtl clearfix">
#  <li>
#  <label>Job Description:</label>
#  job_description   2  years of experience working with python    Strong analytical skills    Ability to churn scripting solutions with a quick turnaround time    Inclination to... <a href="https://www.timesjobs.com/job-detail/python-engineer-east-india-securities-ltd-kolkata-2-to-5-yrs-jobid-O9JSjUglX3hzpSvf__PLUS__uAgZw==&amp;source=srp" target="_blank">More Details</a>
#  </li>
#  <li>
#  <label>KeySkills:</label>
#  <span class="srp-skills">
#  <span><strong class="blkclor">python</strong></span>
#  <span>hadoop</span>
#  <span>machine learning</span>
#  </span> </li>
#  <!--
#              <li>
#                <i class="material-icons">location_on</i>
#                Kolkata
#                </li>
#  -->
#  </ul>
#  <div class="list-job-bt clearfix">
#  <div class="list-action">
#  <div class="applied-dtl clearfix" id="showPostApplyData_70471066">
#  <a class="waves-effect waves-light btn" href="javascript:callExtJobApply('70471066','adId=O9JSjUglX3hzpSvf__PLUS__uAgZw==&amp;compName=Career Progress Consultants','TJPFSRP');" onclick="trackClickEvent('View_AND_Apply_SRP','from_srp_externalJobs');logViewUSBT('apply','70471066','python  ,  hadoop  ,  machine learning','Kolkata','2 - 5','IT Software : Software Products &amp; Services','4','')">Apply</a>
#  <span class="jobs-status clearfix">
#  <!--
#  -->
#  </span>
#  <span class="sim-posted">
#  <span>Posted few days ago</span>
#  </span>
#  </div>
#  </div>
#  </div>
#  </li>,
#  <li class="clearfix job-bx wht-shd-bx">
#  <header class="clearfix">
#  <!--
#  -->
#  <!-- -->
#  <h2>
#  <a href="https://www.timesjobs.com/job-detail/python-developer-laksh-human-resource-mumbai-1-to-3-yrs-jobid-uUEqcx71MRdzpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','70474644','rest  ,  python  ,  django  ,  git','Mumbai','1 - 3','IT Software : Software Products &amp; Services','5','' )" target="_blank">
#  <strong class="blkclor">Python</strong> Developer</a> </h2>
#  <h3 class="joblist-comp-name">
#      LAKSH HUMAN RESOURCE
#
#      </h3>
#  </header>
#  <ul class="top-jd-dtl clearfix">
#  <li><i class="material-icons">card_travel</i>1 - 3 yrs</li>
#  <li>
#  <i class="material-icons">location_on</i>
#  <span title="Mumbai">Mumbai</span>
#  </li>
#  </ul>
#  <ul class="list-job-dtl clearfix">
#  <li>
#  <label>Job Description:</label>
#  Powai ,  Mumbai Python Developer Experience : 1 to 3 yrs Skills Required : Job Summary : 1. Should have extensive knowledge of Python ,  Django frameowrk ,  REST APIs. 2. Shou... <a href="https://www.timesjobs.com/job-detail/python-developer-laksh-human-resource-mumbai-1-to-3-yrs-jobid-uUEqcx71MRdzpSvf__PLUS__uAgZw==&amp;source=srp" target="_blank">More Details</a>
#  </li>
#  <li>
#  <label>KeySkills:</label>
#  <span class="srp-skills">
#  <span>rest</span>
#  <span><strong class="blkclor">python</strong></span>
#  <span>django</span>
#  <span>git</span>
#  </span> </li>
#  <!--
#              <li>
#                <i class="material-icons">location_on</i>
#                Mumbai
#                </li>
#  -->
#  </ul>
#  <div class="list-job-bt clearfix">
#  <div class="list-action">
#  <div class="applied-dtl clearfix" id="showPostApplyData_70474644">
#  <a class="waves-effect waves-light btn" href="javascript:callExtJobApply('70474644','adId=uUEqcx71MRdzpSvf__PLUS__uAgZw==&amp;compName=Career Progress Consultants','TJPFSRP');" onclick="trackClickEvent('View_AND_Apply_SRP','from_srp_externalJobs');logViewUSBT('apply','70474644','rest  ,  python  ,  django  ,  git','Mumbai','1 - 3','IT Software : Software Products &amp; Services','5','')">Apply</a>
#  <span class="jobs-status clearfix">
#  <!--
#  -->
#  </span>
#  <span class="sim-posted">
#  <span>Posted few days ago</span>
#  </span>
#  </div>
#  </div>
#  </div>
#  </li>,
#  <li class="clearfix job-bx wht-shd-bx">
#  <header class="clearfix">
#  <!--
#  -->
#  <!-- -->
#  <h2>
#  <a href="https://www.timesjobs.com/job-detail/python-developer-xonier-technologies-pvt-ltd-noida-greater-noida-2-to-5-yrs-jobid-zOHQ8Tw7IgRzpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','70512425','python  ,  django  ,  testing tools  ,  debugging  ,  storage','Noida/Greater Noida','2 - 5','IT Software : Software Products &amp; Services','6','' )" target="_blank">
#  <strong class="blkclor">Python</strong> Developer</a> </h2>
#  <h3 class="joblist-comp-name">
#      xonier technologies pvt ltd
#
#      </h3>
#  </header>
#  <ul class="top-jd-dtl clearfix">
#  <li><i class="material-icons">card_travel</i>2 - 5 yrs</li>
#  <li>
#  <i class="material-icons">location_on</i>
#  <span title="Noida/Greater Noida">Noida/Greater Noida</span>
#  </li>
#  </ul>
#  <ul class="list-job-dtl clearfix">
#  <li>
#  <label>Job Description:</label>
#  Roles and ResponsibilitiesCoordinating with development teams to determine application requirements.Writing scalable code using Python programming language.Testing and debuggi... <a href="https://www.timesjobs.com/job-detail/python-developer-xonier-technologies-pvt-ltd-noida-greater-noida-2-to-5-yrs-jobid-zOHQ8Tw7IgRzpSvf__PLUS__uAgZw==&amp;source=srp" target="_blank">More Details</a>
#  </li>
#  <li>
#  <label>KeySkills:</label>
#  <span class="srp-skills">
#  <span><strong class="blkclor">python</strong></span>
#  <span>django</span>
#  <span>testing tools</span>
#  <span>debugging</span>
#  <span>storage</span>
#  </span> </li>
#  <!--
#              <li>
#                <i class="material-icons">location_on</i>
#                Noida/Greater Noida
#                </li>
#  -->
#  </ul>
#  <div class="list-job-bt clearfix">
#  <div class="list-action">
#  <div class="applied-dtl clearfix" id="showPostApplyData_70512425">
#  <a class="waves-effect waves-light btn" href="javascript:callExtJobApply('70512425','adId=zOHQ8Tw7IgRzpSvf__PLUS__uAgZw==&amp;compName=Career Progress Consultants','TJPFSRP');" onclick="trackClickEvent('View_AND_Apply_SRP','from_srp_externalJobs');logViewUSBT('apply','70512425','python  ,  django  ,  testing tools  ,  debugging  ,  storage','Noida/Greater Noida','2 - 5','IT Software : Software Products &amp; Services','6','')">Apply</a>
#  <span class="jobs-status clearfix">
#  <!--
#         <i class="material-icons trnding-up" title="Recently posted job, Recruiter is actively looking for candidates">check_circle</i>
#
#  -->
#  </span>
#  <span class="sim-posted">
#  <span>Posted few days ago</span>
#  </span>
#  </div>
#  </div>
#  </div>
#  </li>,
#  <li class="clearfix job-bx wht-shd-bx">
#  <header class="clearfix">
#  <!--
#  -->
#  <!-- -->
#  <h2>
#  <a href="https://www.timesjobs.com/job-detail/python-developer-day1-technologies-bengaluru-bangalore-2-to-3-yrs-jobid-5yTMsjn5vkJzpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','70509926','rest  ,  python  ,  django  ,  git  ,  postgresql  ,  sql  ,  docker','Bengaluru / Bangalore','2 - 3','IT Software : Software Products &amp; Services','7','' )" target="_blank">
#  <strong class="blkclor">Python</strong> Developer</a> </h2>
#  <h3 class="joblist-comp-name">
#      day1 technologies
#
#      </h3>
#  </header>
#  <ul class="top-jd-dtl clearfix">
#  <li><i class="material-icons">card_travel</i>2 - 3 yrs</li>
#  <li>
#  <i class="material-icons">location_on</i>
#  <span title="Bengaluru / Bangalore">Bengaluru / Bangalore</span>
#  </li>
#  </ul>
#  <ul class="list-job-dtl clearfix">
#  <li>
#  <label>Job Description:</label>
#  Reading Time: Less than 1 minuteJob Requirement:Very good object-oriented Python3 knowledgeExperience in Django ORMGood knowledge of GitKnowledge of Python Pandas ,  SQL ,  Po... <a href="https://www.timesjobs.com/job-detail/python-developer-day1-technologies-bengaluru-bangalore-2-to-3-yrs-jobid-5yTMsjn5vkJzpSvf__PLUS__uAgZw==&amp;source=srp" target="_blank">More Details</a>
#  </li>
#  <li>
#  <label>KeySkills:</label>
#  <span class="srp-skills">
#  <span>rest</span>
#  <span><strong class="blkclor">python</strong></span>
#  <span>django</span>
#  <span>git</span>
#  <span>postgresql</span>
#  <span>sql</span>
#  <span>docker</span>
#  </span> </li>
#  <!--
#              <li>
#                <i class="material-icons">location_on</i>
#                Bengaluru / Bangalore
#                </li>
#  -->
#  </ul>
#  <div class="list-job-bt clearfix">
#  <div class="list-action">
#  <div class="applied-dtl clearfix" id="showPostApplyData_70509926">
#  <a class="waves-effect waves-light btn" href="javascript:callExtJobApply('70509926','adId=5yTMsjn5vkJzpSvf__PLUS__uAgZw==&amp;compName=Career Progress Consultants','TJPFSRP');" onclick="trackClickEvent('View_AND_Apply_SRP','from_srp_externalJobs');logViewUSBT('apply','70509926','rest  ,  python  ,  django  ,  git  ,  postgresql  ,  sql  ,  docker','Bengaluru / Bangalore','2 - 3','IT Software : Software Products &amp; Services','7','')">Apply</a>
#  <span class="jobs-status clearfix">
#  <!--
#         <i class="material-icons trnding-up" title="Recently posted job, Recruiter is actively looking for candidates">check_circle</i>
#
#  -->
#  </span>
#  <span class="sim-posted">
#  <span>Posted few days ago</span>
#  </span>
#  </div>
#  </div>
#  </div>
#  </li>,
#  <li class="clearfix job-bx wht-shd-bx">
#  <header class="clearfix">
#  <!--
#  -->
#  <!-- -->
#  <h2>
#  <a href="https://www.timesjobs.com/job-detail/python-developer-zenga-tv-gurgaon-2-to-5-yrs-jobid-cQGeFhRqgNdzpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','70486681','python  ,  django  ,  html5  ,  javascript','Gurgaon','2 - 5','IT Software : Software Products &amp; Services','8','' )" target="_blank">
#  <strong class="blkclor">Python</strong> Developer</a> </h2>
#  <h3 class="joblist-comp-name">
#      zenga tv
#
#      </h3>
#  </header>
#  <ul class="top-jd-dtl clearfix">
#  <li><i class="material-icons">card_travel</i>2 - 5 yrs</li>
#  <li>
#  <i class="material-icons">location_on</i>
#  <span title="Gurgaon">Gurgaon</span>
#  </li>
#  </ul>
#  <ul class="list-job-dtl clearfix">
#  <li>
#  <label>Job Description:</label>
#  Python Developer &gt; GurgaonPositions: 4 Experience Required: 2  Years Responsibilities :Translate application storyboards and use cases into functional applicationsDesign ,  bu... <a href="https://www.timesjobs.com/job-detail/python-developer-zenga-tv-gurgaon-2-to-5-yrs-jobid-cQGeFhRqgNdzpSvf__PLUS__uAgZw==&amp;source=srp" target="_blank">More Details</a>
#  </li>
#  <li>
#  <label>KeySkills:</label>
#  <span class="srp-skills">
#  <span><strong class="blkclor">python</strong></span>
#  <span>django</span>
#  <span>html5</span>
#  <span>javascript</span>
#  </span> </li>
#  <!--
#              <li>
#                <i class="material-icons">location_on</i>
#                Gurgaon
#                </li>
#  -->
#  </ul>
#  <div class="list-job-bt clearfix">
#  <div class="list-action">
#  <div class="applied-dtl clearfix" id="showPostApplyData_70486681">
#  <a class="waves-effect waves-light btn" href="javascript:callExtJobApply('70486681','adId=cQGeFhRqgNdzpSvf__PLUS__uAgZw==&amp;compName=Career Progress Consultants','TJPFSRP');" onclick="trackClickEvent('View_AND_Apply_SRP','from_srp_externalJobs');logViewUSBT('apply','70486681','python  ,  django  ,  html5  ,  javascript','Gurgaon','2 - 5','IT Software : Software Products &amp; Services','8','')">Apply</a>
#  <span class="jobs-status clearfix">
#  <!--
#  -->
#  </span>
#  <span class="sim-posted">
#  <span>Posted few days ago</span>
#  </span>
#  </div>
#  </div>
#  </div>
#  </li>,
#  <li class="clearfix job-bx wht-shd-bx">
#  <header class="clearfix">
#  <!--
#  -->
#  <!-- -->
#  <h2>
#  <a href="https://www.timesjobs.com/job-detail/python-developer-infinity-group-noida-greater-noida-2-to-5-yrs-jobid-WKzksjq__PLUS__GXxzpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','70473236','python  ,  css  ,  django  ,  html  ,  bootstrap','Noida/Greater Noida','2 - 5','IT Software : Software Products &amp; Services','9','' )" target="_blank">
#  <strong class="blkclor">PYTHON</strong> Developer</a> </h2>
#  <h3 class="joblist-comp-name">
#      INFINITY GROUP
#
#      </h3>
#  </header>
#  <ul class="top-jd-dtl clearfix">
#  <li><i class="material-icons">card_travel</i>2 - 5 yrs</li>
#  <li>
#  <i class="material-icons">location_on</i>
#  <span title="Noida/Greater Noida">Noida/Greater Noida</span>
#  </li>
#  </ul>
#  <ul class="list-job-dtl clearfix">
#  <li>
#  <label>Job Description:</label>
#  DescriptionPosition: PYTHON DeveloperNo. of Requirement: 02- One for Fresher  ( Stipend ) - One for ExperienceEducation: B.Tech ,  M.Tech ,  BCA ,  MCA ,  Bsc  ( Computer ) Ex... <a href="https://www.timesjobs.com/job-detail/python-developer-infinity-group-noida-greater-noida-2-to-5-yrs-jobid-WKzksjq__PLUS__GXxzpSvf__PLUS__uAgZw==&amp;source=srp" target="_blank">More Details</a>
#  </li>
#  <li>
#  <label>KeySkills:</label>
#  <span class="srp-skills">
#  <span><strong class="blkclor">python</strong></span>
#  <span>css</span>
#  <span>django</span>
#  <span>html</span>
#  <span>bootstrap</span>
#  </span> </li>
#  <!--
#              <li>
#                <i class="material-icons">location_on</i>
#                Noida/Greater Noida
#                </li>
#  -->
#  </ul>
#  <div class="list-job-bt clearfix">
#  <div class="list-action">
#  <div class="applied-dtl clearfix" id="showPostApplyData_70473236">
#  <a class="waves-effect waves-light btn" href="javascript:callExtJobApply('70473236','adId=WKzksjq__PLUS__GXxzpSvf__PLUS__uAgZw==&amp;compName=Career Progress Consultants','TJPFSRP');" onclick="trackClickEvent('View_AND_Apply_SRP','from_srp_externalJobs');logViewUSBT('apply','70473236','python  ,  css  ,  django  ,  html  ,  bootstrap','Noida/Greater Noida','2 - 5','IT Software : Software Products &amp; Services','9','')">Apply</a>
#  <span class="jobs-status clearfix">
#  <!--
#  -->
#  </span>
#  <span class="sim-posted">
#  <span>Posted few days ago</span>
#  </span>
#  </div>
#  </div>
#  </div>
#  </li>,
#  <li class="clearfix job-bx wht-shd-bx">
#  <header class="clearfix">
#  <!--
#  -->
#  <!-- -->
#  <h2>
#  <a href="https://www.timesjobs.com/job-detail/python-developer-dreamajax-technologies-bengaluru-bangalore-4-to-7-yrs-jobid-55iKtddZNCdzpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','70470934','python  ,  django  ,  api  ,  sql  ,  nosql','Bengaluru / Bangalore','4 - 7','IT Software : Software Products &amp; Services','10','' )" target="_blank">
#  <strong class="blkclor">PYTHON</strong> DEVELOPER</a> </h2>
#  <h3 class="joblist-comp-name">
#      DREAMAJAX TECHNOLOGIES
#
#      </h3>
#  </header>
#  <ul class="top-jd-dtl clearfix">
#  <li><i class="material-icons">card_travel</i>4 - 7 yrs</li>
#  <li>
#  <i class="material-icons">location_on</i>
#  <span title="Bengaluru / Bangalore">Bengaluru / Bangalore</span>
#  </li>
#  </ul>
#  <ul class="list-job-dtl clearfix">
#  <li>
#  <label>Job Description:</label>
#  PYTHON DEVELOPER B.E  /  B.Tech  /  MCA  /  M.Sc. ,  or equivalent with 4  years of Strong Experience as a Python developerStrong hands on experience on Core Python ,  Django ... <a href="https://www.timesjobs.com/job-detail/python-developer-dreamajax-technologies-bengaluru-bangalore-4-to-7-yrs-jobid-55iKtddZNCdzpSvf__PLUS__uAgZw==&amp;source=srp" target="_blank">More Details</a>
#  </li>
#  <li>
#  <label>KeySkills:</label>
#  <span class="srp-skills">
#  <span><strong class="blkclor">python</strong></span>
#  <span>django</span>
#  <span>api</span>
#  <span>sql</span>
#  <span>nosql</span>
#  </span> </li>
#  <!--
#              <li>
#                <i class="material-icons">location_on</i>
#                Bengaluru / Bangalore
#                </li>
#  -->
#  </ul>
#  <div class="list-job-bt clearfix">
#  <div class="list-action">
#  <div class="applied-dtl clearfix" id="showPostApplyData_70470934">
#  <a class="waves-effect waves-light btn" href="javascript:callExtJobApply('70470934','adId=55iKtddZNCdzpSvf__PLUS__uAgZw==&amp;compName=Career Progress Consultants','TJPFSRP');" onclick="trackClickEvent('View_AND_Apply_SRP','from_srp_externalJobs');logViewUSBT('apply','70470934','python  ,  django  ,  api  ,  sql  ,  nosql','Bengaluru / Bangalore','4 - 7','IT Software : Software Products &amp; Services','10','')">Apply</a>
#  <span class="jobs-status clearfix">
#  <!--
#  -->
#  </span>
#  <span class="sim-posted">
#  <span>Posted few days ago</span>
#  </span>
#  </div>
#  </div>
#  </div>
#  </li>,
#  <li class="clearfix job-bx wht-shd-bx">
#  <header class="clearfix">
#  <!--
#  -->
#  <!-- -->
#  <h2>
#  <a href="https://www.timesjobs.com/job-detail/python-developer-datagrid-solutions-mumbai-2-to-3-yrs-jobid-hdLfInxHIFxzpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','70470226','python  ,  database  ,  django  ,  mysql  ,  api','Mumbai','2 - 3','IT Software : Software Products &amp; Services','11','' )" target="_blank">
#  <strong class="blkclor">Python</strong> Developer</a> </h2>
#  <h3 class="joblist-comp-name">
#      Datagrid Solutions
#
#      </h3>
#  </header>
#  <ul class="top-jd-dtl clearfix">
#  <li><i class="material-icons">card_travel</i>2 - 3 yrs</li>
#  <li>
#  <i class="material-icons">location_on</i>
#  <span title="Mumbai">Mumbai</span>
#  </li>
#  </ul>
#  <ul class="list-job-dtl clearfix">
#  <li>
#  <label>Job Description:</label>
#  Write well designed and optimized codeContribute in all phases of development lifecycle - troubleshoot ,  test and maintain the core product and database to ensure strong opti... <a href="https://www.timesjobs.com/job-detail/python-developer-datagrid-solutions-mumbai-2-to-3-yrs-jobid-hdLfInxHIFxzpSvf__PLUS__uAgZw==&amp;source=srp" target="_blank">More Details</a>
#  </li>
#  <li>
#  <label>KeySkills:</label>
#  <span class="srp-skills">
#  <span><strong class="blkclor">python</strong></span>
#  <span>database</span>
#  <span>django</span>
#  <span>mysql</span>
#  <span>api</span>
#  </span> </li>
#  <!--
#              <li>
#                <i class="material-icons">location_on</i>
#                Mumbai
#                </li>
#  -->
#  </ul>
#  <div class="list-job-bt clearfix">
#  <div class="list-action">
#  <div class="applied-dtl clearfix" id="showPostApplyData_70470226">
#  <a class="waves-effect waves-light btn" href="javascript:callExtJobApply('70470226','adId=hdLfInxHIFxzpSvf__PLUS__uAgZw==&amp;compName=Career Progress Consultants','TJPFSRP');" onclick="trackClickEvent('View_AND_Apply_SRP','from_srp_externalJobs');logViewUSBT('apply','70470226','python  ,  database  ,  django  ,  mysql  ,  api','Mumbai','2 - 3','IT Software : Software Products &amp; Services','11','')">Apply</a>
#  <span class="jobs-status clearfix">
#  <!--
#  -->
#  </span>
#  <span class="sim-posted">
#  <span>Posted few days ago</span>
#  </span>
#  </div>
#  </div>
#  </div>
#  </li>,
#  <li class="clearfix job-bx wht-shd-bx">
#  <header class="clearfix">
#  <!--
#  -->
#  <!-- -->
#  <h2>
#  <a href="https://www.timesjobs.com/job-detail/python-developer-electrobrain-modern-technologies-pvt-ltd-chandigarh-vijayawada-visakhapatnam-mangalore-mysoru-mysore-2-to-7-yrs-jobid-bxAE6LmL141zpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','70648234','science  ,  Matplotlib  ,  GIT  ,  Pandas  ,  AWS  ,  Numpy  ,  Python  ,  Django  ,  Mongodb  ,  Node  ,  js','Chandigarh,  Vijayawada,  Visakhapatnam,  Mangalore,  Mysoru / Mysore','2 - 7','IT Software : Software Products &amp; Services','12','' )" target="_blank">
#  <strong class="blkclor">Python</strong> Developer</a> </h2>
#  <h3 class="joblist-comp-name">
#      Electrobrain modern technologies pvt ltd
#       <span class="comp-more">(<a class="jobs-frm-comp" href="/candidate/companySearchResult.html?from=submit&amp;encid=eOt8R__PLUS__C2pyzAYi4CfQotyg==&amp;searchType=byCompany&amp;luceneResultSize=25">More Jobs</a>) </span>
#  </h3>
#  </header>
#  <ul class="top-jd-dtl clearfix">
#  <li><i class="material-icons">card_travel</i>2 - 7 yrs</li>
#  <li><i class="material-icons rupee">₹</i>Rs 7.20 - 11.00 Lacs p.a.</li>
#  <li>
#  <i class="material-icons">location_on</i>
#  <span title="Chandigarh,  Vijayawada,  Visakhapatnam,  Mangalore,  Mysoru / Mysore">Chandigarh,  Vijayawada,  Visakhapatnam,  Mangalore,  Mysoru / Mysore</span>
#  </li>
#  </ul>
#  <ul class="list-job-dtl clearfix">
#  <li>
#  <label>Job Description:</label>
#  Coordinating with development teams to determine application requirements.Writing scalable code using Python programming language.Testing and debugging applications.developing... <a href="https://www.timesjobs.com/job-detail/python-developer-electrobrain-modern-technologies-pvt-ltd-chandigarh-vijayawada-visakhapatnam-mangalore-mysoru-mysore-2-to-7-yrs-jobid-bxAE6LmL141zpSvf__PLUS__uAgZw==&amp;source=srp" target="_blank">More Details</a>
#  </li>
#  <li>
#  <label>KeySkills:</label>
#  <span class="srp-skills">
#  <span>science</span>
#  <span>Matplotlib</span>
#  <span>GIT</span>
#  <span>Pandas</span>
#  <span>AWS</span>
#  <span>Numpy</span>
#  <span><strong class="blkclor">Python</strong></span>
#  <span>Django</span>
#  <span>Mongodb</span>
#  <span>Node</span>
#  <span>js</span>
#  </span> </li>
#  <!--
#              <li>
#                <i class="material-icons">location_on</i>
#                Chandigarh,  Vijayawada,  Visakhapatnam,  Mangalore,  Mysoru / Mysore
#                </li>
#  -->
#  </ul>
#  <div class="list-job-bt clearfix">
#  <div class="list-action">
#  <div class="applied-dtl clearfix" id="showPostApplyData_70648234">
#  <button class="waves-effect waves-light btn" id="apply_70648234" onclick="trackClickEvent('View_AND_Apply_SRP','from_srp_others');jobSRPApplyFuncInline('70648234','INT','TJPFSRP');logViewUSBT('apply','70648234','science  ,  Matplotlib  ,  GIT  ,  Pandas  ,  AWS  ,  Numpy  ,  Python  ,  Django  ,  Mongodb  ,  Node  ,  js','Chandigarh,  Vijayawada,  Visakhapatnam,  Mangalore,  Mysoru / Mysore','2 - 7','IT Software : Software Products &amp; Services','12','')">Apply</button>
#  <span class="jobs-status clearfix">
#  <!--
#  -->
#  </span>
#  <span class="sim-posted">
#  <span>Posted 2 days ago</span>
#  </span>
#  </div>
#  </div>
#  </div>
#  </li>,
#  <li class="clearfix job-bx wht-shd-bx">
#  <header class="clearfix">
#  <!--
#  -->
#  <!-- -->
#  <h2>
#  <a href="https://www.timesjobs.com/job-detail/python-programmer-3ri-technologies-pvt-ltd-pune-0-to-1-yrs-jobid-KCSVZHaFaptzpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','70627543','python  ,  Pandas  ,   PyQt5  ,   Matplotlib  ,   Openpyxl','Pune','0 - 1','IT Software : Software Products &amp; Services','13','' )" target="_blank">
#  <strong class="blkclor">Python</strong> Programmer</a> </h2>
#  <h3 class="joblist-comp-name">
#      3RI Technologies Pvt Ltd
#
#      </h3>
#  </header>
#  <ul class="top-jd-dtl clearfix">
#  <li><i class="material-icons">card_travel</i>0 - 1 yrs</li>
#  <li>
#  <i class="material-icons">location_on</i>
#  <span title="Pune">Pune</span>
#  </li>
#  </ul>
#  <ul class="list-job-dtl clearfix">
#  <li>
#  <label>Job Description:</label>
#  Python ProgrammerExp Required: 0-1 yearNo. of Position: 2 to 3Salary Range: 2  3 lakhsJob Location: PuneThe candidate should ideally be a science or business graduate with:cle... <a href="https://www.timesjobs.com/job-detail/python-programmer-3ri-technologies-pvt-ltd-pune-0-to-1-yrs-jobid-KCSVZHaFaptzpSvf__PLUS__uAgZw==&amp;source=srp" target="_blank">More Details</a>
#  </li>
#  <li>
#  <label>KeySkills:</label>
#  <span class="srp-skills">
#  <span><strong class="blkclor">python</strong></span>
#  <span>Pandas</span>
#  <span>PyQt5</span>
#  <span>Matplotlib</span>
#  <span>Openpyxl</span>
#  </span> </li>
#  <!--
#              <li>
#                <i class="material-icons">location_on</i>
#                Pune
#                </li>
#  -->
#  </ul>
#  <div class="list-job-bt clearfix">
#  <div class="list-action">
#  <div class="applied-dtl clearfix" id="showPostApplyData_70627543">
#  <a class="waves-effect waves-light btn" href="javascript:callExtJobApply('70627543','adId=KCSVZHaFaptzpSvf__PLUS__uAgZw==&amp;compName=Career Progress Consultants','TJPFSRP');" onclick="trackClickEvent('View_AND_Apply_SRP','from_srp_externalJobs');logViewUSBT('apply','70627543','python  ,  Pandas  ,   PyQt5  ,   Matplotlib  ,   Openpyxl','Pune','0 - 1','IT Software : Software Products &amp; Services','13','')">Apply</a>
#  <span class="jobs-status clearfix">
#  <!--
#  -->
#  </span>
#  <span class="sim-posted">
#  <span>Posted few days ago</span>
#  </span>
#  </div>
#  </div>
#  </div>
#  </li>,
#  <li class="clearfix job-bx wht-shd-bx">
#  <header class="clearfix">
#  <!--
#  -->
#  <!-- -->
#  <h2>
#  <a href="https://www.timesjobs.com/job-detail/python-developer-connecting-2-work-thiruvananthapuram-5-to-10-yrs-jobid-15ymTnn475xzpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','70492057','python  ,  storage  ,  django  ,  testing tools  ,  debugging','Thiruvananthapuram','5 - 10','IT Software : Software Products &amp; Services','14','' )" target="_blank">
#  <strong class="blkclor">Python</strong> Developer</a> </h2>
#  <h3 class="joblist-comp-name">
#      CONNECTING 2 WORK
#
#      </h3>
#  </header>
#  <ul class="top-jd-dtl clearfix">
#  <li><i class="material-icons">card_travel</i>5 - 10 yrs</li>
#  <li>
#  <i class="material-icons">location_on</i>
#  <span title="Thiruvananthapuram">Thiruvananthapuram</span>
#  </li>
#  </ul>
#  <ul class="list-job-dtl clearfix">
#  <li>
#  <label>Job Description:</label>
#  Job Description We are looking for an experienced Python developer to join our engineering team and help us create dynamic software applications for our clients. In this role ... <a href="https://www.timesjobs.com/job-detail/python-developer-connecting-2-work-thiruvananthapuram-5-to-10-yrs-jobid-15ymTnn475xzpSvf__PLUS__uAgZw==&amp;source=srp" target="_blank">More Details</a>
#  </li>
#  <li>
#  <label>KeySkills:</label>
#  <span class="srp-skills">
#  <span><strong class="blkclor">python</strong></span>
#  <span>storage</span>
#  <span>django</span>
#  <span>testing tools</span>
#  <span>debugging</span>
#  </span> </li>
#  <!--
#              <li>
#                <i class="material-icons">location_on</i>
#                Thiruvananthapuram
#                </li>
#  -->
#  </ul>
#  <div class="list-job-bt clearfix">
#  <div class="list-action">
#  <div class="applied-dtl clearfix" id="showPostApplyData_70492057">
#  <a class="waves-effect waves-light btn" href="javascript:callExtJobApply('70492057','adId=15ymTnn475xzpSvf__PLUS__uAgZw==&amp;compName=Career Progress Consultants','TJPFSRP');" onclick="trackClickEvent('View_AND_Apply_SRP','from_srp_externalJobs');logViewUSBT('apply','70492057','python  ,  storage  ,  django  ,  testing tools  ,  debugging','Thiruvananthapuram','5 - 10','IT Software : Software Products &amp; Services','14','')">Apply</a>
#  <span class="jobs-status clearfix">
#  <!--
#  -->
#  </span>
#  <span class="sim-posted">
#  <span>Posted few days ago</span>
#  </span>
#  </div>
#  </div>
#  </div>
#  </li>,
#  <li class="clearfix job-bx wht-shd-bx">
#  <header class="clearfix">
#  <!--
#  -->
#  <!-- -->
#  <h2>
#  <a href="https://www.timesjobs.com/job-detail/python-developer-connecting-2-work-cochin-kochi-ernakulam-2-to-3-yrs-jobid-CZYubAVhafJzpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','70491804','database  ,  python  ,  css  ,  rest api  ,  html  ,  javascript','Cochin/ Kochi/ Ernakulam','2 - 3','IT Software : Software Products &amp; Services','15','' )" target="_blank">
#  <strong class="blkclor">Python</strong> Developer</a> </h2>
#  <h3 class="joblist-comp-name">
#      CONNECTING 2 WORK
#
#      </h3>
#  </header>
#  <ul class="top-jd-dtl clearfix">
#  <li><i class="material-icons">card_travel</i>2 - 3 yrs</li>
#  <li>
#  <i class="material-icons">location_on</i>
#  <span title="Cochin/ Kochi/ Ernakulam">Cochin/ Kochi/ Ernakulam</span>
#  </li>
#  </ul>
#  <ul class="list-job-dtl clearfix">
#  <li>
#  <label>Job Description:</label>
#  Job Description Responsibilities Define application objectives by analysing user requirements. Design and create database schema for applications. Create and maintain web / mo... <a href="https://www.timesjobs.com/job-detail/python-developer-connecting-2-work-cochin-kochi-ernakulam-2-to-3-yrs-jobid-CZYubAVhafJzpSvf__PLUS__uAgZw==&amp;source=srp" target="_blank">More Details</a>
#  </li>
#  <li>
#  <label>KeySkills:</label>
#  <span class="srp-skills">
#  <span>database</span>
#  <span><strong class="blkclor">python</strong></span>
#  <span>css</span>
#  <span>rest api</span>
#  <span>html</span>
#  <span>javascript</span>
#  </span> </li>
#  <!--
#              <li>
#                <i class="material-icons">location_on</i>
#                Cochin/ Kochi/ Ernakulam
#                </li>
#  -->
#  </ul>
#  <div class="list-job-bt clearfix">
#  <div class="list-action">
#  <div class="applied-dtl clearfix" id="showPostApplyData_70491804">
#  <a class="waves-effect waves-light btn" href="javascript:callExtJobApply('70491804','adId=CZYubAVhafJzpSvf__PLUS__uAgZw==&amp;compName=Career Progress Consultants','TJPFSRP');" onclick="trackClickEvent('View_AND_Apply_SRP','from_srp_externalJobs');logViewUSBT('apply','70491804','database  ,  python  ,  css  ,  rest api  ,  html  ,  javascript','Cochin/ Kochi/ Ernakulam','2 - 3','IT Software : Software Products &amp; Services','15','')">Apply</a>
#  <span class="jobs-status clearfix">
#  <!--
#  -->
#  </span>
#  <span class="sim-posted">
#  <span>Posted few days ago</span>
#  </span>
#  </div>
#  </div>
#  </div>
#  </li>,
#  <li class="clearfix job-bx wht-shd-bx">
#  <header class="clearfix">
#  <!--
#  -->
#  <!--   <span class="comp-logo-bg"> <img src="https://static.timesjobs.com/images_cand/tj_images/insider_img/logos/003616.gif" alt="Advaiya Solutions Pvt Ltd" title="Advaiya Solutions Pvt Ltd"/> </span> -->
#  <h2>
#  <a href="https://www.timesjobs.com/job-detail/python-developer-advaiya-solutions-pvt-ltd-4-to-16-yrs-jobid-6X89RJpO6VZzpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','70631968','rest  ,  python  ,  ajax  ,  javascript  ,  django  ,  java  ,  xml  ,  json  ,  api  ,  angularjs','','4 - 16','IT Software : Software Products &amp; Services','16','' )" target="_blank">
#  <strong class="blkclor">Python</strong> Developer</a> </h2>
#  <h3 class="joblist-comp-name">
#      Advaiya Solutions Pvt Ltd
#
#      </h3>
#  </header>
#  <ul class="top-jd-dtl clearfix">
#  <li><i class="material-icons">card_travel</i>4 - 16 yrs</li>
#  <li>
#  <i class="material-icons">location_on</i>
#  <span title=""></span>
#  </li>
#  </ul>
#  <ul class="list-job-dtl clearfix">
#  <li>
#  <label>Job Description:</label>
#  Experience in python ,  with around 4-16 years ,  with a strong emphasis on testing and documentation.Experience with modern client-side  /  API technologies such as AngularJS... <a href="https://www.timesjobs.com/job-detail/python-developer-advaiya-solutions-pvt-ltd-4-to-16-yrs-jobid-6X89RJpO6VZzpSvf__PLUS__uAgZw==&amp;source=srp" target="_blank">More Details</a>
#  </li>
#  <li>
#  <label>KeySkills:</label>
#  <span class="srp-skills">
#  <span>rest</span>
#  <span><strong class="blkclor">python</strong></span>
#  <span>ajax</span>
#  <span>javascript</span>
#  <span>django</span>
#  <span>java</span>
#  <span>xml</span>
#  <span>json</span>
#  <span>api</span>
#  <span>angularjs</span>
#  </span> </li>
#  <!--
#              <li>
#                <i class="material-icons">location_on</i>
#
#                </li>
#  -->
#  </ul>
#  <div class="list-job-bt clearfix">
#  <div class="list-action">
#  <div class="applied-dtl clearfix" id="showPostApplyData_70631968">
#  <a class="waves-effect waves-light btn" href="javascript:callExtJobApply('70631968','adId=6X89RJpO6VZzpSvf__PLUS__uAgZw==&amp;compName=Career Progress Consultants','TJPFSRP');" onclick="trackClickEvent('View_AND_Apply_SRP','from_srp_externalJobs');logViewUSBT('apply','70631968','rest  ,  python  ,  ajax  ,  javascript  ,  django  ,  java  ,  xml  ,  json  ,  api  ,  angularjs','','4 - 16','IT Software : Software Products &amp; Services','16','')">Apply</a>
#  <span class="jobs-status clearfix">
#  <!--
#         <i class="material-icons trnding-up" title="Recently posted job, Recruiter is actively looking for candidates">check_circle</i>
#
#  -->
#  </span>
#  <span class="sim-posted">
#  <span>Posted few days ago</span>
#  </span>
#  </div>
#  </div>
#  </div>
#  </li>,
#  <li class="clearfix job-bx wht-shd-bx">
#  <header class="clearfix">
#  <!--
#  -->
#  <!-- -->
#  <h2>
#  <a href="https://www.timesjobs.com/job-detail/python-developer-seven-consultancy-surat-9-to-12-yrs-jobid-Oi3jhp3isY5zpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','70479291','Python programming  ,  programming language  ,  front-end developer','Surat','9 - 12','IT Software : Software Products &amp; Services','17','' )" target="_blank">
#  <strong class="blkclor">Python</strong> Developer</a> </h2>
#  <h3 class="joblist-comp-name">
#      SEVEN CONSULTANCY
#
#      </h3>
#  </header>
#  <ul class="top-jd-dtl clearfix">
#  <li><i class="material-icons">card_travel</i>9 - 12 yrs</li>
#  <li>
#  <i class="material-icons">location_on</i>
#  <span title="Surat">Surat</span>
#  </li>
#  </ul>
#  <ul class="list-job-dtl clearfix">
#  <li>
#  <label>Job Description:</label>
#  JOB DETAILSCoordinating with development teams to determine application requirementsWriting scalable code using Python programming languageTesting and debugging applicationsDe... <a href="https://www.timesjobs.com/job-detail/python-developer-seven-consultancy-surat-9-to-12-yrs-jobid-Oi3jhp3isY5zpSvf__PLUS__uAgZw==&amp;source=srp" target="_blank">More Details</a>
#  </li>
#  <li>
#  <label>KeySkills:</label>
#  <span class="srp-skills">
#  <span><strong class="blkclor">Python</strong> programming</span>
#  <span>programming language</span>
#  <span>front-end developer</span>
#  </span> </li>
#  <!--
#              <li>
#                <i class="material-icons">location_on</i>
#                Surat
#                </li>
#  -->
#  </ul>
#  <div class="list-job-bt clearfix">
#  <div class="list-action">
#  <div class="applied-dtl clearfix" id="showPostApplyData_70479291">
#  <a class="waves-effect waves-light btn" href="javascript:callExtJobApply('70479291','adId=Oi3jhp3isY5zpSvf__PLUS__uAgZw==&amp;compName=Career Progress Consultants','TJPFSRP');" onclick="trackClickEvent('View_AND_Apply_SRP','from_srp_externalJobs');logViewUSBT('apply','70479291','Python programming  ,  programming language  ,  front-end developer','Surat','9 - 12','IT Software : Software Products &amp; Services','17','')">Apply</a>
#  <span class="jobs-status clearfix">
#  <!--
#  -->
#  </span>
#  <span class="sim-posted">
#  <span>Posted few days ago</span>
#  </span>
#  </div>
#  </div>
#  </div>
#  </li>,
#  <li class="clearfix job-bx wht-shd-bx">
#  <header class="clearfix">
#  <!--
#  -->
#  <!-- -->
#  <h2>
#  <a href="https://www.timesjobs.com/job-detail/python-developer-websharan-infotech-pune-0-to-3-yrs-jobid-Ujq9FCZjPgtzpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','70486310','python  ,  problem solving  ,  software project  ,  software engineering','Pune','0 - 3','IT Software : Software Products &amp; Services','18','' )" target="_blank">
#  <strong class="blkclor">Python</strong> Developer</a> </h2>
#  <h3 class="joblist-comp-name">
#      websharan infotech
#
#      </h3>
#  </header>
#  <ul class="top-jd-dtl clearfix">
#  <li><i class="material-icons">card_travel</i>0 - 3 yrs</li>
#  <li>
#  <i class="material-icons">location_on</i>
#  <span title="Pune">Pune</span>
#  </li>
#  </ul>
#  <ul class="list-job-dtl clearfix">
#  <li>
#  <label>Job Description:</label>
#  JOB DESCRIPTION 1. Design software solution by analyzing problem definition. Develops moderately complex software using python if necessary shell script ,  or other selected l... <a href="https://www.timesjobs.com/job-detail/python-developer-websharan-infotech-pune-0-to-3-yrs-jobid-Ujq9FCZjPgtzpSvf__PLUS__uAgZw==&amp;source=srp" target="_blank">More Details</a>
#  </li>
#  <li>
#  <label>KeySkills:</label>
#  <span class="srp-skills">
#  <span><strong class="blkclor">python</strong></span>
#  <span>problem solving</span>
#  <span>software project</span>
#  <span>software engineering</span>
#  </span> </li>
#  <!--
#              <li>
#                <i class="material-icons">location_on</i>
#                Pune
#                </li>
#  -->
#  </ul>
#  <div class="list-job-bt clearfix">
#  <div class="list-action">
#  <div class="applied-dtl clearfix" id="showPostApplyData_70486310">
#  <a class="waves-effect waves-light btn" href="javascript:callExtJobApply('70486310','adId=Ujq9FCZjPgtzpSvf__PLUS__uAgZw==&amp;compName=Career Progress Consultants','TJPFSRP');" onclick="trackClickEvent('View_AND_Apply_SRP','from_srp_externalJobs');logViewUSBT('apply','70486310','python  ,  problem solving  ,  software project  ,  software engineering','Pune','0 - 3','IT Software : Software Products &amp; Services','18','')">Apply</a>
#  <span class="jobs-status clearfix">
#  <!--
#  -->
#  </span>
#  <span class="sim-posted">
#  <span>Posted few days ago</span>
#  </span>
#  </div>
#  </div>
#  </div>
#  </li>,
#  <li class="clearfix job-bx wht-shd-bx">
#  <header class="clearfix">
#  <!--
#  -->
#  <!-- -->
#  <h2>
#  <a href="https://www.timesjobs.com/job-detail/python-developer-analytics-vidhya-gurgaon-5-to-8-yrs-jobid-1yt0PivXVN1zpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','70467189','python  ,  css  ,  html5  ,  html  ,  ajax  ,  javascript','Gurgaon','5 - 8','IT Software : Software Products &amp; Services','19','' )" target="_blank">
#  <strong class="blkclor">Python</strong> Developer</a> </h2>
#  <h3 class="joblist-comp-name">
#      Analytics Vidhya
#
#      </h3>
#  </header>
#  <ul class="top-jd-dtl clearfix">
#  <li><i class="material-icons">card_travel</i>5 - 8 yrs</li>
#  <li>
#  <i class="material-icons">location_on</i>
#  <span title="Gurgaon">Gurgaon</span>
#  </li>
#  </ul>
#  <ul class="list-job-dtl clearfix">
#  <li>
#  <label>Job Description:</label>
#  Python Developer- Gurgaon-  ( 3  Years of Experience ) Python Developer- Gurgaon-  ( 3  Years of Experience )  A Client of Analytics VidhyaGurugram INR 3 - 10 LPA Experience :... <a href="https://www.timesjobs.com/job-detail/python-developer-analytics-vidhya-gurgaon-5-to-8-yrs-jobid-1yt0PivXVN1zpSvf__PLUS__uAgZw==&amp;source=srp" target="_blank">More Details</a>
#  </li>
#  <li>
#  <label>KeySkills:</label>
#  <span class="srp-skills">
#  <span><strong class="blkclor">python</strong></span>
#  <span>css</span>
#  <span>html5</span>
#  <span>html</span>
#  <span>ajax</span>
#  <span>javascript</span>
#  </span> </li>
#  <!--
#              <li>
#                <i class="material-icons">location_on</i>
#                Gurgaon
#                </li>
#  -->
#  </ul>
#  <div class="list-job-bt clearfix">
#  <div class="list-action">
#  <div class="applied-dtl clearfix" id="showPostApplyData_70467189">
#  <a class="waves-effect waves-light btn" href="javascript:callExtJobApply('70467189','adId=1yt0PivXVN1zpSvf__PLUS__uAgZw==&amp;compName=Career Progress Consultants','TJPFSRP');" onclick="trackClickEvent('View_AND_Apply_SRP','from_srp_externalJobs');logViewUSBT('apply','70467189','python  ,  css  ,  html5  ,  html  ,  ajax  ,  javascript','Gurgaon','5 - 8','IT Software : Software Products &amp; Services','19','')">Apply</a>
#  <span class="jobs-status clearfix">
#  <!--
#  -->
#  </span>
#  <span class="sim-posted">
#  <span>Posted few days ago</span>
#  </span>
#  </div>
#  </div>
#  </div>
#  </li>,
#  <li class="clearfix job-bx wht-shd-bx">
#  <header class="clearfix">
#  <!--
#  -->
#  <!-- -->
#  <h2>
#  <a href="https://www.timesjobs.com/job-detail/python-developer-innovator-web-solutions-pvt-ltd-mumbai-5-to-8-yrs-jobid-Lb8uLETPZjVzpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','70473832','rest  ,  python  ,  django  ,  web developer  ,  mysql  ,  api','Mumbai','5 - 8','IT Software : Software Products &amp; Services','20','' )" target="_blank">
#  <strong class="blkclor">Python</strong> Developer</a> </h2>
#  <h3 class="joblist-comp-name">
#      InnOvator Web Solutions Pvt.Ltd.
#
#      </h3>
#  </header>
#  <ul class="top-jd-dtl clearfix">
#  <li><i class="material-icons">card_travel</i>5 - 8 yrs</li>
#  <li>
#  <i class="material-icons">location_on</i>
#  <span title="Mumbai">Mumbai</span>
#  </li>
#  </ul>
#  <ul class="list-job-dtl clearfix">
#  <li>
#  <label>Job Description:</label>
#  Job Category: DevelopmentJob Type: Full TimeJob Location: Malad  ( W ) We are looking for a Python Web Developer responsible for managing the interchange of data between the s... <a href="https://www.timesjobs.com/job-detail/python-developer-innovator-web-solutions-pvt-ltd-mumbai-5-to-8-yrs-jobid-Lb8uLETPZjVzpSvf__PLUS__uAgZw==&amp;source=srp" target="_blank">More Details</a>
#  </li>
#  <li>
#  <label>KeySkills:</label>
#  <span class="srp-skills">
#  <span>rest</span>
#  <span><strong class="blkclor">python</strong></span>
#  <span>django</span>
#  <span>web developer</span>
#  <span>mysql</span>
#  <span>api</span>
#  </span> </li>
#  <!--
#              <li>
#                <i class="material-icons">location_on</i>
#                Mumbai
#                </li>
#  -->
#  </ul>
#  <div class="list-job-bt clearfix">
#  <div class="list-action">
#  <div class="applied-dtl clearfix" id="showPostApplyData_70473832">
#  <a class="waves-effect waves-light btn" href="javascript:callExtJobApply('70473832','adId=Lb8uLETPZjVzpSvf__PLUS__uAgZw==&amp;compName=Career Progress Consultants','TJPFSRP');" onclick="trackClickEvent('View_AND_Apply_SRP','from_srp_externalJobs');logViewUSBT('apply','70473832','rest  ,  python  ,  django  ,  web developer  ,  mysql  ,  api','Mumbai','5 - 8','IT Software : Software Products &amp; Services','20','')">Apply</a>
#  <span class="jobs-status clearfix">
#  <!--
#  -->
#  </span>
#  <span class="sim-posted">
#  <span>Posted few days ago</span>
#  </span>
#  </div>
#  </div>
#  </div>
#  </li>,
#  <li class="clearfix job-bx wht-shd-bx">
#  <header class="clearfix">
#  <!--
#  -->
#  <!-- -->
#  <h2>
#  <a href="https://www.timesjobs.com/job-detail/python-developer-3ri-technologies-pvt-ltd-pune-0-to-1-yrs-jobid-S9R7triGKgpzpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','70465143','python  ,  database  ,  security  ,  django  ,  git  ,  mobile','Pune','0 - 1','IT Software : Software Products &amp; Services','21','' )" target="_blank">
#  <strong class="blkclor">Python</strong> Developer</a> </h2>
#  <h3 class="joblist-comp-name">
#      3RI Technologies Pvt Ltd
#
#      </h3>
#  </header>
#  <ul class="top-jd-dtl clearfix">
#  <li><i class="material-icons">card_travel</i>0 - 1 yrs</li>
#  <li>
#  <i class="material-icons">location_on</i>
#  <span title="Pune">Pune</span>
#  </li>
#  </ul>
#  <ul class="list-job-dtl clearfix">
#  <li>
#  <label>Job Description:</label>
#  Python DeveloperPosition: Python DeveloperExperience: 0-1  yrsRoles  &amp;  Responsibilities:Understanding differences between multiple delivery platforms such as mobile vs deskto... <a href="https://www.timesjobs.com/job-detail/python-developer-3ri-technologies-pvt-ltd-pune-0-to-1-yrs-jobid-S9R7triGKgpzpSvf__PLUS__uAgZw==&amp;source=srp" target="_blank">More Details</a>
#  </li>
#  <li>
#  <label>KeySkills:</label>
#  <span class="srp-skills">
#  <span><strong class="blkclor">python</strong></span>
#  <span>database</span>
#  <span>security</span>
#  <span>django</span>
#  <span>git</span>
#  <span>mobile</span>
#  </span> </li>
#  <!--
#              <li>
#                <i class="material-icons">location_on</i>
#                Pune
#                </li>
#  -->
#  </ul>
#  <div class="list-job-bt clearfix">
#  <div class="list-action">
#  <div class="applied-dtl clearfix" id="showPostApplyData_70465143">
#  <a class="waves-effect waves-light btn" href="javascript:callExtJobApply('70465143','adId=S9R7triGKgpzpSvf__PLUS__uAgZw==&amp;compName=Career Progress Consultants','TJPFSRP');" onclick="trackClickEvent('View_AND_Apply_SRP','from_srp_externalJobs');logViewUSBT('apply','70465143','python  ,  database  ,  security  ,  django  ,  git  ,  mobile','Pune','0 - 1','IT Software : Software Products &amp; Services','21','')">Apply</a>
#  <span class="jobs-status clearfix">
#  <!--
#  -->
#  </span>
#  <span class="sim-posted">
#  <span>Posted few days ago</span>
#  </span>
#  </div>
#  </div>
#  </div>
#  </li>,
#  <li class="clearfix job-bx wht-shd-bx">
#  <header class="clearfix">
#  <!--
#  -->
#  <!-- -->
#  <h2>
#  <a href="https://www.timesjobs.com/job-detail/python-developer-dealscorner-ahmedabad-1-to-4-yrs-jobid-fldd74GZxP5zpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','70470273','python  ,  css  ,  oops  ,  linux  ,  debugging  ,  html  ,  javascript','Ahmedabad','1 - 4','IT Software : Software Products &amp; Services','22','' )" target="_blank">
#  <strong class="blkclor">Python</strong> Developer</a> </h2>
#  <h3 class="joblist-comp-name">
#      DealsCorner
#
#      </h3>
#  </header>
#  <ul class="top-jd-dtl clearfix">
#  <li><i class="material-icons">card_travel</i>1 - 4 yrs</li>
#  <li>
#  <i class="material-icons">location_on</i>
#  <span title="Ahmedabad">Ahmedabad</span>
#  </li>
#  </ul>
#  <ul class="list-job-dtl clearfix">
#  <li>
#  <label>Job Description:</label>
#  Python Developer Min. Experience: 1 YearsLocation: Ahmedabad ,  Gujarat ,  IndiaQualities:Clear thinker with the ability to simplify and explain process / flow in clear verbat... <a href="https://www.timesjobs.com/job-detail/python-developer-dealscorner-ahmedabad-1-to-4-yrs-jobid-fldd74GZxP5zpSvf__PLUS__uAgZw==&amp;source=srp" target="_blank">More Details</a>
#  </li>
#  <li>
#  <label>KeySkills:</label>
#  <span class="srp-skills">
#  <span><strong class="blkclor">python</strong></span>
#  <span>css</span>
#  <span>oops</span>
#  <span>linux</span>
#  <span>debugging</span>
#  <span>html</span>
#  <span>javascript</span>
#  </span> </li>
#  <!--
#              <li>
#                <i class="material-icons">location_on</i>
#                Ahmedabad
#                </li>
#  -->
#  </ul>
#  <div class="list-job-bt clearfix">
#  <div class="list-action">
#  <div class="applied-dtl clearfix" id="showPostApplyData_70470273">
#  <a class="waves-effect waves-light btn" href="javascript:callExtJobApply('70470273','adId=fldd74GZxP5zpSvf__PLUS__uAgZw==&amp;compName=Career Progress Consultants','TJPFSRP');" onclick="trackClickEvent('View_AND_Apply_SRP','from_srp_externalJobs');logViewUSBT('apply','70470273','python  ,  css  ,  oops  ,  linux  ,  debugging  ,  html  ,  javascript','Ahmedabad','1 - 4','IT Software : Software Products &amp; Services','22','')">Apply</a>
#  <span class="jobs-status clearfix">
#  <!--
#  -->
#  </span>
#  <span class="sim-posted">
#  <span>Posted few days ago</span>
#  </span>
#  </div>
#  </div>
#  </div>
#  </li>,
#  <li class="clearfix job-bx wht-shd-bx">
#  <header class="clearfix">
#  <!--
#  -->
#  <!-- -->
#  <h2>
#  <a href="https://www.timesjobs.com/job-detail/python-developer-wing-global-it-services-panchkula-2-to-5-yrs-jobid-__PLUS__8RZpYIjbidzpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','70486495','spring boot  ,  python  ,  java  ,  django  ,  jpa  ,  hibernate','Panchkula','2 - 5','IT Software : Software Products &amp; Services','23','' )" target="_blank">
#  <strong class="blkclor">Python</strong> Developer</a> </h2>
#  <h3 class="joblist-comp-name">
#      Wing Global IT Services
#
#      </h3>
#  </header>
#  <ul class="top-jd-dtl clearfix">
#  <li><i class="material-icons">card_travel</i>2 - 5 yrs</li>
#  <li>
#  <i class="material-icons">location_on</i>
#  <span title="Panchkula">Panchkula</span>
#  </li>
#  </ul>
#  <ul class="list-job-dtl clearfix">
#  <li>
#  <label>Job Description:</label>
#  Qualifications: Graduation completedSkills required:Strong skills in Java coding with Spring Boot  &amp; amp; Hibernate / JPA.Good knowledge of Django framework.server knowledge w... <a href="https://www.timesjobs.com/job-detail/python-developer-wing-global-it-services-panchkula-2-to-5-yrs-jobid-__PLUS__8RZpYIjbidzpSvf__PLUS__uAgZw==&amp;source=srp" target="_blank">More Details</a>
#  </li>
#  <li>
#  <label>KeySkills:</label>
#  <span class="srp-skills">
#  <span>spring boot</span>
#  <span><strong class="blkclor">python</strong></span>
#  <span>java</span>
#  <span>django</span>
#  <span>jpa</span>
#  <span>hibernate</span>
#  </span> </li>
#  <!--
#              <li>
#                <i class="material-icons">location_on</i>
#                Panchkula
#                </li>
#  -->
#  </ul>
#  <div class="list-job-bt clearfix">
#  <div class="list-action">
#  <div class="applied-dtl clearfix" id="showPostApplyData_70486495">
#  <a class="waves-effect waves-light btn" href="javascript:callExtJobApply('70486495','adId=__PLUS__8RZpYIjbidzpSvf__PLUS__uAgZw==&amp;compName=Career Progress Consultants','TJPFSRP');" onclick="trackClickEvent('View_AND_Apply_SRP','from_srp_externalJobs');logViewUSBT('apply','70486495','spring boot  ,  python  ,  java  ,  django  ,  jpa  ,  hibernate','Panchkula','2 - 5','IT Software : Software Products &amp; Services','23','')">Apply</a>
#  <span class="jobs-status clearfix">
#  <!--
#  -->
#  </span>
#  <span class="sim-posted">
#  <span>Posted few days ago</span>
#  </span>
#  </div>
#  </div>
#  </div>
#  </li>,
#  <li class="clearfix job-bx wht-shd-bx">
#  <header class="clearfix">
#  <!--
#  -->
#  <!-- -->
#  <h2>
#  <a href="https://www.timesjobs.com/job-detail/python-odoo-axistechnolabs-ahmedabad-0-to-1-yrs-jobid-Zbmf2OtDaBxzpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','70467713','python  ,  django  ,  it skills  ,  html5  ,  api  ,  jquery','Ahmedabad','0 - 1','IT Software : Software Products &amp; Services','24','' )" target="_blank">
#  <strong class="blkclor">Python</strong> - Odoo</a> </h2>
#  <h3 class="joblist-comp-name">
#      AxisTechnolabs
#
#      </h3>
#  </header>
#  <ul class="top-jd-dtl clearfix">
#  <li><i class="material-icons">card_travel</i>0 - 1 yrs</li>
#  <li>
#  <i class="material-icons">location_on</i>
#  <span title="Ahmedabad">Ahmedabad</span>
#  </li>
#  </ul>
#  <ul class="list-job-dtl clearfix">
#  <li>
#  <label>Job Description:</label>
#  Responsibilities : We are looking for Freshers who want to grow thier career with Axis TechnolabsSuffering from finding dream jobsIT skills Requires for JobsWe can help you to... <a href="https://www.timesjobs.com/job-detail/python-odoo-axistechnolabs-ahmedabad-0-to-1-yrs-jobid-Zbmf2OtDaBxzpSvf__PLUS__uAgZw==&amp;source=srp" target="_blank">More Details</a>
#  </li>
#  <li>
#  <label>KeySkills:</label>
#  <span class="srp-skills">
#  <span><strong class="blkclor">python</strong></span>
#  <span>django</span>
#  <span>it skills</span>
#  <span>html5</span>
#  <span>api</span>
#  <span>jquery</span>
#  </span> </li>
#  <!--
#              <li>
#                <i class="material-icons">location_on</i>
#                Ahmedabad
#                </li>
#  -->
#  </ul>
#  <div class="list-job-bt clearfix">
#  <div class="list-action">
#  <div class="applied-dtl clearfix" id="showPostApplyData_70467713">
#  <a class="waves-effect waves-light btn" href="javascript:callExtJobApply('70467713','adId=Zbmf2OtDaBxzpSvf__PLUS__uAgZw==&amp;compName=Career Progress Consultants','TJPFSRP');" onclick="trackClickEvent('View_AND_Apply_SRP','from_srp_externalJobs');logViewUSBT('apply','70467713','python  ,  django  ,  it skills  ,  html5  ,  api  ,  jquery','Ahmedabad','0 - 1','IT Software : Software Products &amp; Services','24','')">Apply</a>
#  <span class="jobs-status clearfix">
#  <!--
#  -->
#  </span>
#  <span class="sim-posted">
#  <span>Posted few days ago</span>
#  </span>
#  </div>
#  </div>
#  </div>
#  </li>,
#  <li class="clearfix job-bx wht-shd-bx">
#  <header class="clearfix">
#  <!--
#  -->
#  <!-- -->
#  <h2>
#  <a href="https://www.timesjobs.com/job-detail/python-developer-infostretch-solution-pvt-ltd-mexico-4-to-6-yrs-jobid-__SLASH__tErmJfd44xzpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','70523556','python development  ,   cloud deployment  ,   data structures  ,   devops culture  ,   unit testing   ,  apache  ,  java  ,  software engineering  ,  api  ,  mq  ,  nosql  ,  messaging  ,  fundamentals  ,  storage  ,  database  ,  python scripting  ,  git  ,  mongodb  ,  cloud services  ,  mobile  ,  infrastructure','Mexico','4 - 6','IT Software : Software Products &amp; Services','25','' )" target="_blank">
#  <strong class="blkclor">Python</strong> Developer</a> </h2>
#  <h3 class="joblist-comp-name">
#      Infostretch Solution Pvt Ltd
#
#      </h3>
#  </header>
#  <ul class="top-jd-dtl clearfix">
#  <li><i class="material-icons">card_travel</i>4 - 6 yrs</li>
#  <li>
#  <i class="material-icons">location_on</i>
#  <span title="Mexico">Mexico</span>
#  </li>
#  </ul>
#  <ul class="list-job-dtl clearfix">
#  <li>
#  <label>Job Description:</label>
#  # ## Position: Python Developer### Software Engineering### Location: Any ,  Mexico**About Apexon:**Apexon is a digital-first technology services firm specializing in accelerat... <a href="https://www.timesjobs.com/job-detail/python-developer-infostretch-solution-pvt-ltd-mexico-4-to-6-yrs-jobid-__SLASH__tErmJfd44xzpSvf__PLUS__uAgZw==&amp;source=srp" target="_blank">More Details</a>
#  </li>
#  <li>
#  <label>KeySkills:</label>
#  <span class="srp-skills">
#  <span><strong class="blkclor">python</strong> development</span>
#  <span>cloud deployment</span>
#  <span>data structures</span>
#  <span>devops culture</span>
#  <span>unit testing</span>
#  <span>apache</span>
#  <span>java</span>
#  <span>software engineering</span>
#  <span>api</span>
#  <span>mq</span>
#  <span>nosql</span>
#  <span>messaging</span>
#  <span>fundamentals</span>
#  <span>storage</span>
#  <span>database</span>
#  <span><strong class="blkclor">python</strong> scripting</span>
#  <span>git</span>
#  <span>mongodb</span>
#  <span>cloud services</span>
#  <span>mobile</span>
#  <span>infrastructure</span>
#  </span> </li>
#  <!--
#              <li>
#                <i class="material-icons">location_on</i>
#                Mexico
#                </li>
#  -->
#  </ul>
#  <div class="list-job-bt clearfix">
#  <div class="list-action">
#  <div class="applied-dtl clearfix" id="showPostApplyData_70523556">
#  <a class="waves-effect waves-light btn" href="javascript:callExtJobApply('70523556','adId=__SLASH__tErmJfd44xzpSvf__PLUS__uAgZw==&amp;compName=Career Progress Consultants','TJPFSRP');" onclick="trackClickEvent('View_AND_Apply_SRP','from_srp_externalJobs');logViewUSBT('apply','70523556','python development  ,   cloud deployment  ,   data structures  ,   devops culture  ,   unit testing   ,  apache  ,  java  ,  software engineering  ,  api  ,  mq  ,  nosql  ,  messaging  ,  fundamentals  ,  storage  ,  database  ,  python scripting  ,  git  ,  mongodb  ,  cloud services  ,  mobile  ,  infrastructure','Mexico','4 - 6','IT Software : Software Products &amp; Services','25','')">Apply</a>
#  <span class="jobs-status clearfix">
#  <!--
#         <i class="material-icons trnding-up" title="Recently posted job, Recruiter is actively looking for candidates">check_circle</i>
#
#  -->
#  </span>
#  <span class="sim-posted">
#  <span>Posted 5 days ago</span>
#  </span>
#  </div>
#  </div>
#  </div>
#  </li>]

# %%
for job in jobs:
    company=job.find('h3',class_='joblist-comp-name').text.replace(' ','')
    skills=job.find('span',class_='srp-skills').text.replace(' ','')
    published_date=job.find("span",class_='sim-posted').span.text
    print(f'''company: {company}
          skills required : {skills}
          published date: {published_date}\n 
          ______________________________________________________________''')
# Out:
# company:
# arttechnologyandsoftwareindiapvtltd
#
#
#           skills required :
# rest
# python
# database
# django
# api
#
#           published date: Posted few days ago
#
#           ______________________________________________________________
# company:
# CONNECTING2WORK
#
#
#           skills required :
# rest
# python
# django
# mongodb
#
#           published date: Posted few days ago
#
#           ______________________________________________________________
# company:
# youngmindstechnologysolutionspvtltd
#
#
#           skills required :
# python
# html5
# storage
# javascript
# security
# django
#
#           published date: Posted 6 days ago
#
#           ______________________________________________________________
# company:
# eastindiasecuritiesltd.
#
#
#           skills required :
# python
# hadoop
# machinelearning
#
#           published date: Posted few days ago
#
#           ______________________________________________________________
# company:
# LAKSHHUMANRESOURCE
#
#
#           skills required :
# rest
# python
# django
# git
#
#           published date: Posted few days ago
#
#           ______________________________________________________________
# company:
# xoniertechnologiespvtltd
#
#
#           skills required :
# python
# django
# testingtools
# debugging
# storage
#
#           published date: Posted few days ago
#
#           ______________________________________________________________
# company:
# day1technologies
#
#
#           skills required :
# rest
# python
# django
# git
# postgresql
# sql
# docker
#
#           published date: Posted few days ago
#
#           ______________________________________________________________
# company:
# zengatv
#
#
#           skills required :
# python
# django
# html5
# javascript
#
#           published date: Posted few days ago
#
#           ______________________________________________________________
# company:
# INFINITYGROUP
#
#
#           skills required :
# python
# css
# django
# html
# bootstrap
#
#           published date: Posted few days ago
#
#           ______________________________________________________________
# company:
# DREAMAJAXTECHNOLOGIES
#
#
#           skills required :
# python
# django
# api
# sql
# nosql
#
#           published date: Posted few days ago
#
#           ______________________________________________________________
# company:
# DatagridSolutions
#
#
#           skills required :
# python
# database
# django
# mysql
# api
#
#           published date: Posted few days ago
#
#           ______________________________________________________________
# company:
# Electrobrainmoderntechnologiespvtltd
# (MoreJobs)
#
#           skills required :
# science
# Matplotlib
# GIT
# Pandas
# AWS
# Numpy
# Python
# Django
# Mongodb
# Node
# js
#
#           published date: Posted 2 days ago
#
#           ______________________________________________________________
# company:
# 3RITechnologiesPvtLtd
#
#
#           skills required :
# python
# Pandas
# PyQt5
# Matplotlib
# Openpyxl
#
#           published date: Posted few days ago
#
#           ______________________________________________________________
# company:
# CONNECTING2WORK
#
#
#           skills required :
# python
# storage
# django
# testingtools
# debugging
#
#           published date: Posted few days ago
#
#           ______________________________________________________________
# company:
# CONNECTING2WORK
#
#
#           skills required :
# database
# python
# css
# restapi
# html
# javascript
#
#           published date: Posted few days ago
#
#           ______________________________________________________________
# company:
# AdvaiyaSolutionsPvtLtd
#
#
#           skills required :
# rest
# python
# ajax
# javascript
# django
# java
# xml
# json
# api
# angularjs
#
#           published date: Posted few days ago
#
#           ______________________________________________________________
# company:
# SEVENCONSULTANCY
#
#
#           skills required :
# Pythonprogramming
# programminglanguage
# front-enddeveloper
#
#           published date: Posted few days ago
#
#           ______________________________________________________________
# company:
# websharaninfotech
#
#
#           skills required :
# python
# problemsolving
# softwareproject
# softwareengineering
#
#           published date: Posted few days ago
#
#           ______________________________________________________________
# company:
# AnalyticsVidhya
#
#
#           skills required :
# python
# css
# html5
# html
# ajax
# javascript
#
#           published date: Posted few days ago
#
#           ______________________________________________________________
# company:
# InnOvatorWebSolutionsPvt.Ltd.
#
#
#           skills required :
# rest
# python
# django
# webdeveloper
# mysql
# api
#
#           published date: Posted few days ago
#
#           ______________________________________________________________
# company:
# 3RITechnologiesPvtLtd
#
#
#           skills required :
# python
# database
# security
# django
# git
# mobile
#
#           published date: Posted few days ago
#
#           ______________________________________________________________
# company:
# DealsCorner
#
#
#           skills required :
# python
# css
# oops
# linux
# debugging
# html
# javascript
#
#           published date: Posted few days ago
#
#           ______________________________________________________________
# company:
# WingGlobalITServices
#
#
#           skills required :
# springboot
# python
# java
# django
# jpa
# hibernate
#
#           published date: Posted few days ago
#
#           ______________________________________________________________
# company:
# AxisTechnolabs
#
#
#           skills required :
# python
# django
# itskills
# html5
# api
# jquery
#
#           published date: Posted few days ago
#
#           ______________________________________________________________
# company:
# InfostretchSolutionPvtLtd
#
#
#           skills required :
# pythondevelopment
# clouddeployment
# datastructures
# devopsculture
# unittesting
# apache
# java
# softwareengineering
# api
# mq
# nosql
# messaging
# fundamentals
# storage
# database
# pythonscripting
# git
# mongodb
# cloudservices
# mobile
# infrastructure
#
#           published date: Posted 5 days ago
#
#           ______________________________________________________________

# %% [markdown]
# Removing old posts

# %%
for job in jobs:
    published_date=job.find("span",class_='sim-posted').span.text
    if 'few' not in published_date:
        company=job.find('h3',class_='joblist-comp-name').text.replace(' ','')
        skills=job.find('span',class_='srp-skills').text.replace(' ','')
        
        print(f'''company: {company}
            skills required : {skills}
            published date: {published_date}\n 
            ______________________________________________________________''')
# Out:
# company:
# youngmindstechnologysolutionspvtltd
#
#
#             skills required :
# python
# html5
# storage
# javascript
# security
# django
#
#             published date: Posted 6 days ago
#
#             ______________________________________________________________
# company:
# Electrobrainmoderntechnologiespvtltd
# (MoreJobs)
#
#             skills required :
# science
# Matplotlib
# GIT
# Pandas
# AWS
# Numpy
# Python
# Django
# Mongodb
# Node
# js
#
#             published date: Posted 2 days ago
#
#             ______________________________________________________________
# company:
# InfostretchSolutionPvtLtd
#
#
#             skills required :
# pythondevelopment
# clouddeployment
# datastructures
# devopsculture
# unittesting
# apache
# java
# softwareengineering
# api
# mq
# nosql
# messaging
# fundamentals
# storage
# database
# pythonscripting
# git
# mongodb
# cloudservices
# mobile
# infrastructure
#
#             published date: Posted 5 days ago
#
#             ______________________________________________________________

# %%
for job in jobs:
    published_date=job.find("span",class_='sim-posted').span.text
    if '2'  in published_date:
        company=job.find('h3',class_='joblist-comp-name').text.replace(' ','')
        skills=job.find('span',class_='srp-skills').text.replace(' ','')
        
        print(f'''company: {company}
            skills required : {skills}
            published date: {published_date}\n 
            ______________________________________________________________''')
# Out:
# company:
# Electrobrainmoderntechnologiespvtltd
# (MoreJobs)
#
#             skills required :
# science
# Matplotlib
# GIT
# Pandas
# AWS
# Numpy
# Python
# Django
# Mongodb
# Node
# js
#
#             published date: Posted 2 days ago
#
#             ______________________________________________________________

# %% [markdown]
# Prettifying

# %%
for job in jobs:
    published_date=job.find("span",class_='sim-posted').span.text
    if 'few' not in published_date:
        company=job.find('h3',class_='joblist-comp-name').text.replace(' ','')
        skills=job.find('span',class_='srp-skills').text.replace(' ','')
        
        print(f"company: {company}")
        print(f"skills required : {skills.split()}")
        print("______________________________________________________________")
# Out:
# company:
# youngmindstechnologysolutionspvtltd
#
#
# skills required : ['python', 'html5', 'storage', 'javascript', 'security', 'django']
# ______________________________________________________________
# company:
# Electrobrainmoderntechnologiespvtltd
# (MoreJobs)
#
# skills required : ['science', 'Matplotlib', 'GIT', 'Pandas', 'AWS', 'Numpy', 'Python', 'Django', 'Mongodb', 'Node', 'js']
# ______________________________________________________________
# company:
# InfostretchSolutionPvtLtd
#
#
# skills required : ['pythondevelopment', 'clouddeployment', 'datastructures', 'devopsculture', 'unittesting', 'apache', 'java', 'softwareengineering', 'api', 'mq', 'nosql', 'messaging', 'fundamentals', 'storage', 'database', 'pythonscripting', 'git', 'mongodb', 'cloudservices', 'mobile', 'infrastructure']
# ______________________________________________________________
